# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
hf = pd.read_csv('Housing.csv')

# %%
# Feature Selection
selected_features = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']
X = hf[selected_features]
y = hf['price']

# %%
# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=0)

# %%
# Create and train the Linear Regression model
mlr = LinearRegression()
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate the model
pred_mlr = mlr.predict(X_test)
mlr_score = mlr.score(X_test, y_test)
expl_mlr = explained_variance_score(y_test, pred_mlr)

# %%
# Print different regression metrics
print("Multiple Linear Regression Model Score (R-squared):", round(mlr_score * 100, 2))
print("Explained Variance Score:", round(expl_mlr * 100, 2))
print("Mean Absolute Error:", round(mean_absolute_error(y_test, pred_mlr), 2))
print("Mean Squared Error:", round(mean_squared_error(y_test, pred_mlr), 2))
print("Root Mean Squared Error:", round(np.sqrt(mean_squared_error(y_test, pred_mlr)), 2))
# Out:
# Multiple Linear Regression Model Score (R-squared): 62.78
# Explained Variance Score: 63.04
# Mean Absolute Error: 838326.98
# Mean Squared Error: 1291078186404.84
# Root Mean Squared Error: 1136256.22

# %%
# Visualize the relationship between area and price
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(hf.area,hf.price,color='blue',marker='.')
plt.show()
